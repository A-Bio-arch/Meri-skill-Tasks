# %% [markdown]
# # HR Attrition Analysis (EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install missingno

import missingno as msno

# %%
dr=pd.read_csv(r'C:\Users\Fast Computers\Downloads\Data P3 MeriSkill\HR-Employee-Attrition.csv')

# %%
dr.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
dr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
dr.shape
# Out:
# (1470, 35)

# %%
dr.isnull().sum()/100
# Out:
# Age                         0.0
# Attrition                   0.0
# BusinessTravel              0.0
# DailyRate                   0.0
# Department                  0.0
# DistanceFromHome            0.0
# Education                   0.0
# EducationField              0.0
# EmployeeCount               0.0
# EmployeeNumber              0.0
# EnvironmentSatisfaction     0.0
# Gender                      0.0
# HourlyRate                  0.0
# JobInvolvement              0.0
# JobLevel                    0.0
# JobRole                     0.0
# JobSatisfaction             0.0
# MaritalStatus               0.0
# MonthlyIncome               0.0
# MonthlyRate                 0.0
# NumCompaniesWorked          0.0
# Over18                      0.0
# OverTime                    0.0
# PercentSalaryHike           0.0
# PerformanceRating           0.0
# RelationshipSatisfaction    0.0
# StandardHours               0.0
# StockOptionLevel            0.0
# TotalWorkingYears           0.0
# ...

# %%
dr.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
dr.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
dr.duplicated().sum()
# Out:
# 0

# %%
# Create a correlation matrix

correlation_matrix= dr.corr()
plt.figure(figsize=(20,10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation map of numeric variables')
plt.show()
# Out:
# C:\Users\Fast Computers\AppData\Local\Temp\ipykernel_18420\1287527748.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix= dr.corr()

# %%
# Plot counts for categorical variables

sns.countplot(data=dr,x='OverTime')
plt.title( 'over time')
plt.show()

# %%
# Plot the relation between Overtime and Age
sns.countplot(data=dr, x='MaritalStatus')
plt.title('Marital Status')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=dr, y='JobRole')
plt.title('JobRole')
plt.show()

# %%
sns.countplot(data=dr, x='Gender')
plt.title('Gender')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=dr, y='EducationField')
plt.title('Education Field')
plt.show()

# %%
sns.countplot(data=dr, x='Department')
plt.title('Department')
plt.show()

# %%
sns.countplot(data=dr, x='BusinessTravel')
plt.title('Business travel')
plt.show()

# %%
sns.boxplot(data=dr, x='OverTime',y='Age')
plt.title('OverTime and Age')
plt.show()

# %% [markdown]
# # Plotting Numerical Variables

# %%
plt.figure(figsize=(10, 6))
dr['TotalWorkingYears'].hist(bins=10, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Histogram of TotalWorkingYears')
plt.xlabel('TotalWorkingYears')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=dr, x='EducationField', bins=10, color='skyblue', kde=True)
plt.title('Histogram of EducationField')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=dr, x='NumCompaniesWorked', bins=10, color='skyblue', kde=True)
plt.title('Number of Companies Worked')
plt.show()

# %%
sns.histplot(data=dr, x='DistanceFromHome', bins=10, color='skyblue', kde=True)
plt.title('Distance from Home')
plt.show()

# %% [markdown]
# # Salary Analysis

# %%
sns.histplot(data=dr, x='MonthlyIncome', bins=10, color='skyblue', kde=True)
plt.title('MonthlyIncome')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=dr, x='JobRole',y='MonthlyIncome')
plt.title('Salary by job role')
plt.show()

# %% [markdown]
# # Employee satisfaction and performance

# %%
sns.histplot(data=dr, x='JobSatisfaction', bins=10, color='skyblue', kde=True)
plt.title('Job satisfaction Distribution')
plt.show()

# %%
sns.histplot(data=dr, x='PerformanceRating', bins=10, color='skyblue', kde=True)
plt.title('Performance Rating')
plt.show()

# %%
sns.histplot(data=dr, x='YearsAtCompany', bins=10, color='skyblue', kde=True)
plt.title('Employee tenure dustribution')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=dr, x='Age',y='Department')
plt.title('Age Distribution by department')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=dr, x='JobRole',hue='Attrition')
plt.xticks(rotation=90)
plt.title('Attrition by Job Role')
plt.show()
